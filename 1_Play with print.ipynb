# %%
\ = backword slash (Escape charator)

# %%
print("Python")
# Out:
# Python

# %%
print("hello","python")
# Out:
# hello python

# %%
print("Hello \n Python")
# Out:
# Hello
#  Python

# %%
print("Hello","Python",end=" ")
print("Monty","Circus")
# Out:
# Hello Python Monty Circus

# %%
print("Hello","Python","I","Am","From",sep="_",end="*")
print("Monty","Circus",sep='*',end="*\n")
print("Danke")
# Out:
# Hello_Python_I_Am_From*Monty*Circus*
# Danke

# %%
print("This is First time: ")
print("       *")
print("      * *")
print("     *   *")
print("    *     *")
print("   *       *")
print("  *         *")
print(" *           *")
print("****       ****")
print("   *       *    ")
print("   *       *    ")
print("   *       *    ")
print("   *       *    ")
print("   *       *    ")
print("   *********    ")
# Out:
# This is First time:
#        *
#       * *
#      *   *
#     *     *
#    *       *
#   *         *
#  *           *
# ****       ****
#    *       *
#    *       *
#    *       *
#    *       *
#    *       *
#    *********

# %%
print("Let's do this with fewer print(): ")
print("      * \n     *  *\n    *    *\n   ***  ***" )
print("     *  *\n     *  *\n     ****")
# Out:
# Let's do this with fewer print():
#       *
#      *  *
#     *    *
#    ***  ***
#      *  *
#      *  *
#      ****

# %%
print("Higher: ") 
print("         *\n        * *\n       *   *\n      *     *\n     *       *\n    *         *\n   *           *\n  *             *\n *               *")
print("*******     *******\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *******")
# Out:
# Higher:
#          *
#         * *
#        *   *
#       *     *
#      *       *
#     *         *
#    *           *
#   *             *
#  *               *
# *******     *******
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *******

# %%
print("Doubled Vertically: ") 
print("         *\n        * *\n       *   *\n      *     *\n     *       *\n    *         *\n   *           *\n  *             *\n *               *\n*******     *******\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *******\n"*2)
# Out:
# Doubled Vertically:
#          *
#         * *
#        *   *
#       *     *
#      *       *
#     *         *
#    *           *
#   *             *
#  *               *
# *******     *******
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *******
#          *
#         * *
#        *   *
#       *     *
#      *       *
#     *         *
#    *           *
#   *             *
#  *               *
# *******     *******
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *******

# %%
print("Doubled Horizontally: ")

print("       *        "*2)
print("      * *       "*2)
print("     *   *      "*2)
print("    *     *     "*2)
print("   *       *    "*2)
print("  *         *   "*2)
print(" *           *  "*2)
print("****       **** "*2)
print("   *       *    "*2)
print("   *       *    "*2)
print("   *       *    "*2)
print("   *       *    "*2)
print("   *       *    "*2)
print("   *********    "*2)
# Out:
# Doubled Horizontally:
#        *               *
#       * *             * *
#      *   *           *   *
#     *     *         *     *
#    *       *       *       *
#   *         *     *         *
#  *           *   *           *
# ****       **** ****       ****
#    *       *       *       *
#    *       *       *       *
#    *       *       *       *
#    *       *       *       *
#    *       *       *       *
#    *********       *********

# %%
arrow = "         *\n        * *\n       *   *\n      *     *\n     *       *\n    *         *\n   *           *\n  *             *\n *               *\n*******     *******\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *     *\n      *******\n"*2
invert = "\n".join(arrow.split('\n')[::-1])
print(invert)
# Out:
#       *******
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
# *******     *******
#  *               *
#   *             *
#    *           *
#     *         *
#      *       *
#       *     *
#        *   *
#         * *
#          *
#       *******
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
#       *     *
# *******     *******
#  *               *
#   *             *
#    *           *
#     *         *
#      *       *
#       *     *
#        *   *
#         * *
#          *
