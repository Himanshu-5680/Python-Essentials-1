# %%
var = 1
account_balance = 1000.0
client_name = 'John Doe'
print(var, account_balance, client_name)
print(var)
# Out:
# 1 1000.0 John Doe
# 1

# %%
var = 1
print(Var)
# case sensitivity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 var = 1
# ----> 2 print(Var)
#       3 # case sensitivity
#
# NameError: name 'Var' is not defined

# %%
var = 1
print(var)
var = var + 1
print(var)
# Out:
# 1
# 2

# %% [markdown]
#  compound assignment operators (shortcut operators)

# %%
var/= 5 * 2.
print(var)
var += 1
print(var)
# Out:
# 0.5
# 1.5

# %%
var = 100
var = 200 + 300
print(var)
# Out:
# 500

# %% [markdown]
# Pythagorean theorem
# c = √ a2 + √ b2

# %%
a = 3.0
b = 4.0
c = (a ** 2 + b ** 2) ** 0.5
print("c =", c)
# Out:
# c = 5.0

# %%
miles =7.38 * 1.61
miles
# Out:
# 11.8818

# %%
kilometers = 12.25
miles = 7.38

miles_to_kilometers = miles*1.61
kilometers_to_miles = kilometers/1.61


print(miles, "miles is", round(miles_to_kilometers,2), "kilometers")
print(kilometers, "kilometers is", round(kilometers_to_miles,2), "miles")

INR=10
USD=12

INR_to_USD=INR/95.37
USD_to_INR=USD*95.37

print(USD,"$ = ",round(USD_to_INR,2),"₹")
print(INR,"₹ = ",round(INR_to_USD,2),"$")
# Out:
# 7.38 miles is 11.88 kilometers
# 12.25 kilometers is 7.61 miles
# 12 $ =  1144.44 ₹
# 10 ₹ =  0.1 $

# %% [markdown]
# - Sample input       Sample output
# - x = 0              y = -1.0
# - x = 1              y = 3.0
# - x = -1             y = -9.0

# %%
a = 2
x = -1 # Hardcode your test data here.
while x<a: 
    x = float(x)
    # Write your code here.
    y = ((3*x**3)-(2*x**2)+(3*x)-1)
    print("y =", y)
    x+=1
# Out:
# y = -9.0
# y = -1.0
# y = 3.0
