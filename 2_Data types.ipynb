# %% [markdown]
# Integers

# %%
print("2") #str
print(2) #int
# Out:
# 2
# 2

# %% [markdown]
# Octal and hexadecimal numbers

# %%
print(0o123) #Octal numbers
print(0x123) #Hexadecimal numbers
# Out:
# 83
# 291

# %% [markdown]
# Floats

# %% [markdown]
# scientific notation

# %%
print(3E8)
# Out:
# 300000000.0

# %%
print(6.62607E-34)
# Out:
# 6.62607e-34

# %%
print(0.0000000000000000000001)
# Out:
# 1e-22

# %% [markdown]
# Strings

# %%
print("I like \"Monty Python\"")
print('I like "Monty Python"')
# Out:
# I like "Monty Python"
# I like "Monty Python"

# %%
print(      "I'm monty python"        )
print(      'I\'m monty python'       )
# Out:
# I'm monty python
# I'm monty python

# %%
print('')
print("")

# %% [markdown]
# Boolean values

# %%
print(True > False)
print(True < False)
# Out:
# True
# False

# %%
True == 1 , False == 0
# Out:
# (True, True)

# %% [markdown]
# Expected output -
# - "I'm"
# - ""learning""
# - """Python"""

# %%
print('"I\'m"\n""learning""\n"""Python"""')
# Out:
# "I'm"
# ""learning""
# """Python"""

# %%
print("\"I'm\"\n\"\"learning\"\"\n\"\"\"Python\"\"\"")
# Out:
# "I'm"
# ""learning""
# """Python"""

# %%
print("What is the decimal value of the following binary number?  :" , 1011)
1*(2**0)+1*(2**1)+0*(2**2)+1*(2**3)
# Out:
# What is the decimal value of the following binary number?  : 1011
# 11
