# %% [markdown]
# Exponentiation

# %%
print(2**2)
print(2.**3.)
# Out:
# 4
# 8.0

# %% [markdown]
# Multiplication

# %%
print(2.*2.1)
# Out:
# 4.2

# %% [markdown]
# Division

# %%
print(6 / 3)
print(6. / 3.)
# Out:
# 2.0
# 2.0

# %% [markdown]
# ## Integer division (floor division)

# %%
print(6 // 3)
print(6 // 3.)
"Integer division ka result hamesha us nearest lower integer value ki taraf round hota hai jo real"
# Out:
# 2
# 2.0
# 'Integer division ka result hamesha us nearest integer value ki taraf round hota hai jo real (not rounded) result se lesser (chhoti) hoti hai.'

# %% [markdown]
# ## Remainder (modulo)

# %%
print(14 % 4) 
"remainder left after the integer division"
# Out:
# 2
# 'remainder left after the integer division'

# %%
print(12 % 4.5)
# 12 // 4.5 gives 2.0,
# 2.0 * 4.5 gives 9.0,
# 12 - 9.0 gives 3.0.
# Out:
# 3.0

# %% [markdown]
# addition

# %%
print(-4 + 4)
print(-4. + 8)
# Out:
# 0
# 4.0

# %% [markdown]
# substraction

# %%
print(-4 - 4)
print(4. - 8)
print(-1.1)
# Out:
# -8
# -4.0
# -1.1

# %% [markdown]
# ## Operators and their priorities

# %%
2 + 3 * 5
# Out:
# 17

# %%
print(9 % 6 % 2) # from left to right.
# Out:
# 1

# %% [markdown]
# remainder(modulo) (%) uses the left-sided binding.

# %% [markdown]
# Exponentional uses the right-side binding.

# %%
print(2 ** 2 ** 3)
# 2 ** 3 → 8; 2 ** 8 → 256
# Out:
# 256

# %%
# Exercise
print(-3 ** 2)
print(-2 ** 3)
print(-(3 ** 2))
# -9
# -8
# -9
# Out:
# -9
# -8
# -9

# %% [markdown]
# ## List of priorities

# %%
print(2 * 3 % 5) #1
# Out:
# 1

# %% [markdown]
# Operators and parentheses

# %%
print((5 * ((25 % 13) + 100) / (2 * 13)) // 2)
# Out:
# 10.0

# %%
25%13
# Out:
# 12

# %%
12+100
# Out:
# 112

# %%
5*112
# Out:
# 560

# %%
560/26
# Out:
# 21.53846153846154

# %%
21.53846153846154//2
# Out:
# 10.0

# %%
(), ** , *, /, //, % , + , -

# %% [markdown]
# Exercises

# %%
print((2 ** 4), (2 * 4.), (2 * 4))
# Out:
# 16 8.0 8

# %%
print((-2 / 4), (2 / 4), (2 // 4), (-2 // 4))
# -0.5 , 0.5 , 0 , -1
# Out:
# -0.5 0.5 0 -1

# %%
print((2 % -4), (2 % 4), (2 ** 3 ** 2))
# Out:
# -2 2 512

# %%
print((2 ** 3 ** 2)
,2**(3**2)
,2**9)
# Out:
# 512 512 512
